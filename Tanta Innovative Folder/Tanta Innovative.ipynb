# %%
# !where python
# Out:
# C:\Users\ett\Tanta_environment\Scripts\python.exe
# C:\Users\ett\.ms-ad\python.exe
# C:\Users\ett\AppData\Local\Programs\Python\Python313\python.exe
# C:\Users\ett\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\ett\Downloads\07.18 Lagos Business Database - FMF (1)-0 - 07.18 Lagos Business Database - FMF (1)-0.csv",dtype='object')

# %%
df
# Out:
#                       company_name      Sub Sector Industrial Sector  \
# 0               LetsDesign Studios  3d Art Project    3d Art Project
# 1        a/z pluz painting concept  3d Art Project    3d Art Project
# 2       a z plus painting concepts  3d Art Project    3d Art Project
# 3       a z plus painting concepts  3d Art Project    3d Art Project
# 4           enimayo 3d Art program  3d Art Project    3d Art Project
# ...                            ...             ...               ...
# 543173                         NaN             NaN               NaN
# 543174                         NaN             NaN               NaN
# 543175                         NaN             NaN               NaN
# 543176                         NaN             NaN               NaN
# 543177                         NaN             NaN               NaN
#
#                                                   address  state  \
# 0       24, Jaiyeola Street, Ajao Estate, Lagos Mainla...  Lagos
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543178 entries, 0 to 543177
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   company_name       519737 non-null  object
#  1   Sub Sector         369849 non-null  object
#  2   Industrial Sector  33470 non-null   object
#  3   address            519741 non-null  object
#  4   state              519741 non-null  object
#  5   city               519577 non-null  object
#  6   area               368390 non-null  object
#  7   phone_number       519732 non-null  object
#  8   alt_phone_number   180918 non-null  object
#  9   website            54433 non-null   object
#  10  contact_person     376857 non-null  object
#  11  email_address      277317 non-null  object
# dtypes: object(12)
# memory usage: 49.7+ MB

# %%
df.describe(include='all')
# Out:
#                                 company_name         Sub Sector  \
# count                                 519737             369849
# unique                                442824              38916
# top     The Redeemed Christian Church Of God  Churches,Religion
# freq                                    1062               6117
#
#        Industrial Sector                     address   state      city  \
# count              33470                      519741  519741    519577
# unique                33                      437765       2        97
# top          Agriculture  Ikeja  Ikeja Lagos Nigeria   Lagos  Alimosho
# freq                7098                        1434  519740     70755
#
#                  area phone_number alt_phone_number              website  \
# count          368390       519732           180918                54433
# unique           4683       399018           156648                37290
# ...

# %%
df.dtypes
# Out:
# company_name         object
# Sub Sector           object
# Industrial Sector    object
# address              object
# state                object
# city                 object
# area                 object
# phone_number         object
# alt_phone_number     object
# website              object
# contact_person       object
# email_address        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# company_name          23441
# Sub Sector           173329
# Industrial Sector    509708
# address               23437
# state                 23437
# city                  23601
# area                 174788
# phone_number          23446
# alt_phone_number     362260
# website              488745
# contact_person       166321
# email_address        265861
# dtype: int64

# %%
avg_missing_data=df.isnull().mean()
avg_missing_data
# Out:
# company_name         0.043155
# Sub Sector           0.319102
# Industrial Sector    0.938381
# address              0.043148
# state                0.043148
# city                 0.043450
# area                 0.321788
# phone_number         0.043164
# alt_phone_number     0.666927
# website              0.899788
# contact_person       0.306200
# email_address        0.489455
# dtype: float64

# %%
industrialsector_freq=df['Industrial Sector'].value_counts().idxmax()
industrialsector_freq
# Out:
# 'Agriculture'

# %%
df['Industrial Sector'].replace(np.nan,'Agriculture',inplace=True)
# Out:
# C:\Users\ett\AppData\Local\Temp\ipykernel_16528\3394952267.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Industrial Sector'].replace(np.nan,'Agriculture',inplace=True)

# %%
df['state'].value_counts()
# Out:
# state
# Lagos    519740
# state         1
# Name: count, dtype: int64

# %%
df['state'].value_counts().idxmax()
# Out:
# 'Lagos'

# %%
df['state'].replace(np.nan,'Lagos',inplace=True)
# Out:
# C:\Users\ett\AppData\Local\Temp\ipykernel_16528\509288146.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['state'].replace(np.nan,'Lagos',inplace=True)

# %%
df['city'].value_counts().idxmax()
# Out:
# 'Alimosho'

# %%
df['city'].replace(np.nan,'Alimosho',inplace=True)
# Out:
# C:\Users\ett\AppData\Local\Temp\ipykernel_16528\3755946336.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['city'].replace(np.nan,'Alimosho',inplace=True)

# %%
df['website']=df['website'].fillna('http://'+df['company_name']+'.com')
df['website']
# Out:
# 0              http://www.letsdesignstudios.com
# 1          http://a/z pluz painting concept.com
# 2         http://a z plus painting concepts.com
# 3         http://a z plus painting concepts.com
# 4             http://enimayo 3d Art program.com
#                           ...
# 543173                                      NaN
# 543174                                      NaN
# 543175                                      NaN
# 543176                                      NaN
# 543177                                      NaN
# Name: website, Length: 543178, dtype: object

# %%
df['email_address']=df['email_address'].fillna(df['company_name']+'@gmail.com')
df['email_address']
# Out:
# 0         info@letsdesignstudios.com
# 1            abduladams947@gmail.com
# 2            abduladams947@gmail.com
# 3            abduladams947@gmail.com
# 4                 rmayowa6@gmail.com
#                      ...
# 543173     amutaabahsunday@yahoo.com
# 543174        tracy_4jesus@yahoo.com
# 543175          loriweyimi@yahoo.com
# 543176           titiomage@yahoo.com
# 543177         usmansaheed@yahoo.com
# Name: email_address, Length: 543178, dtype: object

# %%
df['area'].value_counts().idxmax()
# Out:
# 'Omole Phase 1'

# %%
df['area'].replace(np.nan,'Omole Phase 1',inplace=True)
# Out:
# C:\Users\ett\AppData\Local\Temp\ipykernel_16528\2641863510.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['area'].replace(np.nan,'Omole Phase 1',inplace=True)

# %%
df['phone_number']=df['phone_number'].fillna('Not Available')

# %%
df['company_name']=df['company_name'].fillna('Not Available')

# %%
df.dropna(subset=['alt_phone_number'],axis=0,inplace=True)

# %%
df.dropna(subset=['contact_person'],axis=0,inplace=True)

# %%
df['Sub Sector'].value_counts().idxmax()
# Out:
# 'Churches,Religion'

# %%
df['Sub Sector'].replace(np.nan,'Churches,Religion',inplace=True)
# Out:
# C:\Users\ett\AppData\Local\Temp\ipykernel_16528\499629955.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sub Sector'].replace(np.nan,'Churches,Religion',inplace=True)

# %%
df.isnull().sum()
# Out:
# company_name         0
# Sub Sector           0
# Industrial Sector    0
# address              0
# state                0
# city                 0
# area                 0
# phone_number         0
# alt_phone_number     0
# website              0
# contact_person       0
# email_address        0
# dtype: int64

# %%
df
# Out:
#                                              company_name  \
# 9                                       Westklass Studios
# 12                             Morningstar technical work
# 14                            Koolarena Resources Limited
# 16                                             highercool
# 19                         Liberty Services International
# ...                                                   ...
# 443345                                        ZOBOClassic
# 443348  Zaccheus Onumbia Diabiezue Memorial Libraries ...
# 443353                          Hartz Cleaners Supply Ltd
# 443363                                              352ng
# 443365                                           didijobs
#
#                                                Sub Sector   Industrial Sector  \
# 9       3D Art Project,Entertainment,Media and Enterta...      3d Art Project
# 12                                     Ac Repair Services  Ac Repair Services
# ...

# %%
df[['company_name','address']]
# Out:
#                                              company_name  \
# 9                                       Westklass Studios
# 12                             Morningstar technical work
# 14                            Koolarena Resources Limited
# 16                                             highercool
# 19                         Liberty Services International
# ...                                                   ...
# 443345                                        ZOBOClassic
# 443348  Zaccheus Onumbia Diabiezue Memorial Libraries ...
# 443353                          Hartz Cleaners Supply Ltd
# 443363                                              352ng
# 443365                                           didijobs
#
#                                                   address
# 9       168, Akarigbo Road, Ajegunle, Ajeromi Ifelodun...
# 12      12, road 12 lekki phase 1, Admiralty Way, Lekk...
# 14      24, Omodara Avenue, Iju Ishaga, Agege, Lagos, ...
# ...

# %%
df['company_name']=df['company_name'].str.title()

# %%
df['address']=df['address'].str.title()

# %%
df=df.apply(lambda x:x.str.strip())

# %%
df.loc[df['Sub Sector'].str.contains('Writers|Womens Wear',regex=True)]
# Out:
#                          company_name  \
# 29781               Dbc Comic Company
# 87468   Posh Makeup And Beauty Studio
# 111886               Figures Boutique
# 111890                   I K Boutique
# 111897                    Mummy Angel
# ...                               ...
# 328043                  Koinage Media
# 328046      King'S Heir Entertainment
# 329500             Mai Provider Media
# 369805                 Tjmax Fashions
# 369833                      Civ Films
#
#                                          Sub Sector Industrial Sector  \
# 29781                                  Arts,Writers       Agriculture
# 87468   Beauty Parlours,Make Up Artists,Womens Wear       Agriculture
# 111886               Boutiques,Clothing,Womens Wear       Agriculture
# 111890               Boutiques,Clothing,Womens Wear       Agriculture
# 111897               Boutiques,Clothing,Womens Wear       Agriculture
# ...                                             ...               ...
# ...

# %%
df['Industrial Sector'].unique()
# Out:
# array(['3d Art Project', 'Ac Repair Services', 'Accessories',
#        'Accident And Emergencies', 'Accommodation', 'Accountants',
#        'Active Life', 'Administration Of Estate', 'Adult School',
#        'Advanced Books', 'Adventure Sports', 'Advertising Agencies',
#        'Advocate', 'Fitness', 'Restaurants', 'Agriculture', 'Aviation',
#        'Food & Beverage', 'Fashion', 'Steel', 'Healthcare', 'Hospitality',
#        'Religion', 'Computer', 'Construction', 'Design', 'Oil & Gas',
#        'Real Estate', 'Education', 'Transport & Logistics', 'Retail',
#        'Manufacturing', 'Storage'], dtype=object)

# %%
df_group=df.groupby(['area', 'Industrial Sector']).size().reset_index(name='count')

# %%
df_group
# Out:
#                area     Industrial Sector  count
# 0         1004 AREA           Agriculture      3
# 1      1004 Estates           Agriculture      4
# 2      1004 Estates           Real Estate      1
# 3        1st Avenue           Agriculture      3
# 4          1st Gate           Agriculture      9
# ...             ...                   ...    ...
# 6951   ketu Ijaniki           Agriculture      1
# 6952  kola Alagbado           Agriculture      1
# 6953           Ògba         Accommodation      1
# 6954           Ògba  Advertising Agencies      2
# 6955           Ògba           Agriculture     26
#
# [6956 rows x 3 columns]

# %%
df_group=df_group.sort_values(['area', 'count'], ascending=False)
df_group
# Out:
#                area     Industrial Sector  count
# 6955           Ògba           Agriculture     26
# 6954           Ògba  Advertising Agencies      2
# 6953           Ògba         Accommodation      1
# 6952  kola Alagbado           Agriculture      1
# 6951   ketu Ijaniki           Agriculture      1
# ...             ...                   ...    ...
# 5          1st Gate              Aviation      1
# 3        1st Avenue           Agriculture      3
# 1      1004 Estates           Agriculture      4
# 2      1004 Estates           Real Estate      1
# 0         1004 AREA           Agriculture      3
#
# [6956 rows x 3 columns]

# %%
df[df['company_name'].str.contains('Hartz Cleaners Supply Ltd')]
# Out:
#                      company_name         Sub Sector Industrial Sector  \
# 443353  Hartz Cleaners Supply Ltd  Churches,Religion       Agriculture
#
#                                                  address  state   city  \
# 443353  Oluwaleyimu St Omole Phase 1 Ikeja Lagos Nigeria  Lagos  Ikeja
#
#                  area phone_number alt_phone_number  \
# 443353  Omole Phase 1   8130229343       7064508854
#
#                                      website  contact_person  \
# 443353  http://Hartz Cleaners Supply Ltd.com  Zoheir OR Tolu
#
#                        email_address
# 443353  info@hartzcleanerssupply.com

# %%
df.loc[443353] = df.loc[443353].replace({'Churches,Religion':'Manufacturing','Agriculture':'retail and wholesale trade'})

# %%
df[df['company_name'].str.contains('Hartz Cleaners Supply Ltd')]
# Out:
#                      company_name     Sub Sector           Industrial Sector  \
# 443353  Hartz Cleaners Supply Ltd  Manufacturing  retail and wholesale trade
#
#                                                  address  state   city  \
# 443353  Oluwaleyimu St Omole Phase 1 Ikeja Lagos Nigeria  Lagos  Ikeja
#
#                  area phone_number alt_phone_number  \
# 443353  Omole Phase 1   8130229343       7064508854
#
#                                      website  contact_person  \
# 443353  http://Hartz Cleaners Supply Ltd.com  Zoheir OR Tolu
#
#                        email_address
# 443353  info@hartzcleanerssupply.com

# %%
df
# Out:
#                                              company_name  \
# 9                                       Westklass Studios
# 12                             Morningstar Technical Work
# 14                            Koolarena Resources Limited
# 16                                             Highercool
# 19                         Liberty Services International
# ...                                                   ...
# 443345                                        Zoboclassic
# 443348  Zaccheus Onumbia Diabiezue Memorial Libraries ...
# 443353                          Hartz Cleaners Supply Ltd
# 443363                                              352Ng
# 443365                                           Didijobs
#
#                                                Sub Sector  \
# 9       3D Art Project,Entertainment,Media and Enterta...
# 12                                     Ac Repair Services
# 14                                     Ac Repair Services
# ...

# %%
df.to_csv('Tanta Innovative Document.csv',index=False)
